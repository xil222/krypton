# %%
import torch
import time
import gc
import math
from scipy import ndimage
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
from cnn.commons import full_inference_e2e, inc_inference_e2e,adaptive_drilldown
from cnn.vgg16 import VGG16
from cnn.resnet18 import ResNet18
from cnn.inception3 import Inception3

from cnn.vgg16_inc_v2 import IncrementalVGG16V2
from cnn.vgg16_inc_v1 import IncrementalVGG16V1
from cnn.resnet18_inc_v2 import IncrementalResNet18V2
from cnn.resnet18_inc_v1 import IncrementalResNet18V1

from cnn.inception3_inc_v2 import IncrementalInception3V2

image_file_path = "../cnn/dog_resized.jpg"
interested_logit_index = 208
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# torch.cuda.synchronize()
prev_time = time.time()
outputs_full = full_inference_e2e(Inception3, image_file_path, 16, 1, interested_logit_index, batch_size=64,
                                  x_size=299, y_size=299, image_size=299)
torch.cuda.synchronize()
full_inference_time = time.time() - prev_time
print("Full Inference Time: " + str(full_inference_time))
# Out:
# ../cnn/commons.py:124: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   orig_image = Variable(loader(orig_image).unsqueeze(0), volatile=True)
# Full Inference Time: 158.439736128

# %%
x = outputs_full
xmax, xmin = x.max(), x.min()
x = 1 - (x - xmin)/(xmax - xmin)

outputs_full_final = x
np.savetxt('temp', outputs_full_final)

plt.imshow(x, cmap=plt.cm.rainbow, interpolation='none')
plt.colorbar()

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
def inc_inference(beta, patch_size=4, stride=1, adaptive=False):
    torch.cuda.synchronize()
    if not adaptive:
        outputs_inc = inc_inference_e2e(IncrementalInception3V2, image_file_path, patch_size, stride, interested_logit_index,
                                  batch_size=64, beta=beta, image_size=299, x_size=299, y_size=299)
    else:
        outputs_inc = adaptive_drilldown(IncrementalInception3V2, image_file_path, patch_size, stride, interested_logit_index,
                                    batch_size=64, beta=beta, percentile=20, image_size=299)
    
    torch.cuda.synchronize()
    x = outputs_inc
    
    #if beta != 1.0:
    #    x = ndimage.gaussian_filter(x, sigma=0.75*(0.5/beta)**2)

    xmax, xmin = x.max(), x.min()
    x = 1 - (x - xmin)/(xmax - xmin)
    return x

# %% [markdown]
# ### Path growth thresholding

# %%
outputs_full_final = np.loadtxt('temp')
times = []
mse = []

for beta in [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3]:
    prev_time = time.time()
    outputs_inc_final = inc_inference(beta, patch_size=16, stride=1)
    inc_inference_time = time.time()-prev_time
    times.append(inc_inference_time)
    mse.append(((outputs_inc_final - outputs_full_final) ** 2).mean(axis=None))
    
    plt.imshow(outputs_inc_final, cmap=plt.cm.rainbow, interpolation='none')
    plt.colorbar()
    label = "BETA: " + str(beta) +" Inference Time: " + str(inc_inference_time)
    print(label)
    plt.show()
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-3-48aa745a027e> in <module>()
#       5 for beta in [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3]:
#       6     prev_time = time.time()
# ----> 7     outputs_inc_final = inc_inference(beta, patch_size=16, stride=1)
#       8     inc_inference_time = time.time()-prev_time
#       9     times.append(inc_inference_time)
#
# <ipython-input-2-2981b370a337> in inc_inference(beta, patch_size, stride, adaptive)
#       3     if not adaptive:
#       4         outputs_inc = inc_inference_e2e(IncrementalInception3V2, image_file_path, patch_size, stride, interested_logit_index,
# ----> 5                                   batch_size=128, beta=beta, image_size=299, x_size=299, y_size=299)
#       6     else:
#       7         outputs_inc = adaptive_drilldown(IncrementalInception3V2, image_file_path, patch_size, stride, interested_logit_index,
#
# /home/snakanda/Work/krypton-cuda/cnn/commons.pyc in inc_inference_e2e(model, file_path, patch_size, stride, logit_index, batch_size, beta, x0, y0, image_size, x_size, y_size, cuda)
#     189         images_batch[j, :, x:x + patch_size, y:y + patch_size] = image_patch
#     190
# --> 191     inc_model = model(images_batch, beta=beta)
#     192     inc_model.eval()
#     193
#
# /home/snakanda/Work/krypton-cuda/cnn/inception3_inc_v2.pyc in __init__(self, in_tensor, beta, gpu)
#      29             in_tensor = in_tensor.cuda()
#      30
# ---> 31         self.initial_result = full_model.forward_materialized(in_tensor).cpu().data.numpy()
#      32         self.full_model = full_model
#      33         self.beta = beta
#
# /home/snakanda/Work/krypton-cuda/cnn/inception3.pyc in forward_materialized(self, x)
#     124         x = self.mixed_6e.forward_materialized(x)
#     125
# --> 126         x = self.mixed_7a.forward_materialized(x)
#     127         x = self.mixed_7b.forward_materialized(x)
#     128         x = self.mixed_7c.forward_materialized(x)
#
# /home/snakanda/Work/krypton-cuda/cnn/inception3.pyc in forward_materialized(self, x)
#     709         self.b3_2 = self.b3_2_op(self.b3_1)
#     710
# --> 711         self.b7_1 = self.b7_1_op(x)
#     712         self.b7_2 = self.b7_2_op(self.b7_1)
#     713         self.b7_3 = self.b7_3_op(self.b7_2)
#
# /home/snakanda/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /home/snakanda/.local/lib/python2.7/site-packages/torch/nn/modules/container.pyc in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /home/snakanda/.local/lib/python2.7/site-packages/torch/nn/modules/module.pyc in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /home/snakanda/.local/lib/python2.7/site-packages/torch/nn/modules/conv.pyc in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: cuda runtime error (2) : out of memory at /pytorch/aten/src/THC/generic/THCStorage.cu:58

# %%
plt.plot(times, mse, marker='o')
plt.grid()
plt.xlabel('runtime (s)')
plt.ylabel('MSE')

# %%
outputs_inc_final[0,0]

# %% [markdown]
# ### Adaptive drill-down

# %%
outputs_full_final = np.loadtxt('temp')
times = []
mse = []

for beta in [1.0, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3]:
    prev_time = time.time()
    outputs_inc_final = inc_inference(beta, patch_size=16, stride=1, adaptive=True)
    inc_inference_time = time.time()-prev_time
    times.append(inc_inference_time)
    mse.append(((outputs_inc_final - outputs_full_final) ** 2).mean(axis=None))
    
    plt.imshow(outputs_inc_final, cmap=plt.cm.rainbow, interpolation='none')
    plt.colorbar()
    label = "BETA: " + str(beta) +" Inference Time: " + str(inc_inference_time)
    print(label)
    plt.show()
    
plt.plot(times, mse, marker='o')
plt.grid()
plt.xlabel('runtime (s)')
plt.ylabel('MSE')

# %%
outputs_full_final = np.loadtxt('temp')
temp = np.abs(np.around(outputs_full_final, decimals=5) - np.around(outputs_inc_final, decimals=5))

# %%
plt.imshow(temp, cmap=plt.cm.rainbow, interpolation='none')
plt.colorbar()
